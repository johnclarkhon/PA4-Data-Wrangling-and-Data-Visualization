# %% [markdown]
# # EXPERIMENT 4 - Data Wrangling and Data Visualization (PANDAS)

# %% [markdown]
# ### Name: HONRADO, John Clark D.
# ### Section: 2ECE-A
# ### Date: September 17, 2024

# %% [markdown]
# ### --------------------------------------------------------------------------------------------

# %% [markdown]
# ## ECE BOARD EXAM PROBLEM:

# %%
#Import related library
import pandas as pd

# %% [markdown]
# ### 1. Create the following data frames based on the format provided:

# %% [markdown]
# #### a.) Filename: Instru = [“Name”, “GEAS”, “Electronics >70”]; where track is constant as Instrumentation and hometown Luzonn

# %%
# Use pandas to read the CSV file into a DataFrame
board2 = pd.read_excel('board2.xlsx')
board2
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
Instru = board2.loc[board2['Track']=='Instrumentation', ['Name', 'GEAS', 'Electronics']].loc[board2['Electronics']>70].loc[board2['Hometown']=='Luzon']
Instru
# Out:
#    Name  GEAS  Electronics
# 0    S1    75           89
# 7    S8    64           81
# 29  S30    57           81

# %% [markdown]
# #### b.) Filename: Mindy = [ “Name”, “Track”, “Electronics”, “Average >=55”]; where hometown is constant as Mindanao and gender Female

# %%
board2['Average'] = round(board2[['Math', 'Electronics', 'GEAS', 'Communication']].mean(axis=1),2)
Mindy = board2.loc[board2['Gender']=='Female', ['Name', 'Track', 'Average']].loc[board2['Average']>=55].loc[board2['Hometown']=='Mindanao']
Mindy
# Out:
#    Name             Track  Average
# 1    S2     Communication    67.25
# 2    S3   Instrumentation    72.75
# 14  S15  Microelectronics    59.00
# 16  S17  Microelectronics    70.50
# 19  S20     Communication    66.50

# %% [markdown]
# ### 2. Create a visualization that shows how the different features contributes to average grade. Does chosen track in college, gender, or hometown contributes to a higher average score?

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.bar(board2['Track'], board2['Average'])
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# #### Relationship of College Tracks vs Average Score with order Microelectronics, Communication, and Instrumentation in highest to lowest score

# %%
plt.figure(figsize=(10, 6))
plt.bar(board2['Gender'], board2['Average'])
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# ##### Relationship of Gender vs Average Score with Female having higher score than Male

# %%
plt.figure(figsize=(10, 6))
plt.bar(board2['Hometown'], board2['Average'])
# Out:
# <BarContainer object of 30 artists>

# %% [markdown]
# ##### Relationship of Hometown vs Average Score with order Luzon, Visayas, Mindanao in higest to lowest score
